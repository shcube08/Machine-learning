# %% [markdown]
# ## Maximum Likelihood Function

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm

# %%
mu = 5
sigma = 1

# %%
x = np.random.normal(mu, sigma, 10)
print(x)
# Out:
# [4.17968649 5.26354558 3.14628468 4.69508643 5.77195304 4.40427687
#  3.79301969 4.66489107 4.26735949 4.87205118]

# %%
def getLikelihood(x, mu):
    return (1/np.sqrt(2*np.pi))*np.exp(-0.5*(x-mu)**2)

# %%
mean = np.linspace(0,10,50)
likelihood = []
mu = []
for i in range(len(mean)):
    y = getLikelihood(x, mean[i])
    likelihood.append(np.prod(y))
    mu.append(mean[i])

# %%
plt.plot(mu, likelihood)

# %%
def logLikelihood(likelihood):
    return np.log10(likelihood)

# %%
log_likelihood = logLikelihood(likelihood)

# %%
plt.plot(mu, log_likelihood)
